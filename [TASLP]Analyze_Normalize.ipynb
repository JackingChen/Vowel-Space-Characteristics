# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed Jun 14 17:37:15 2023

@author: jack
"""

import pandas as pd
import argparse
import os
from addict import Dict
def get_args():
    # we add compulsary arguments as named arguments for readability
    parser = argparse.ArgumentParser()
    parser.add_argument('--Normalize_way', default='proposed',
                            help='')

    args = parser.parse_args(args=[])
    return args
args = get_args()

ReadPath='/media/jack/workspace/DisVoice/RESULTS/Merged_xlsx/'
Normalized_ways_lst=['func1','func2','func3','func4','func7','func10','func13','func14','func15',
                     'func16','func17','proposed']
NormalizedNewways_lst = [n for n in Normalized_ways_lst if n != 'proposed']

fusion_indexes=[
'static_feautre_LOC+dynamic_feature_LOC+dynamic_feature_phonation-LOC_columns+DEP_columns+LOCDEP_Trend_D_cols+LOCDEP_Syncrony_cols',
'static_feautre_LOC+dynamic_feature_LOC+dynamic_feature_phonation-LOC_columns+DEP_columns+LOCDEP_Trend_D_cols',
'static_feautre_LOC+dynamic_feature_LOC+dynamic_feature_phonation-LOC_columns+DEP_columns+LOCDEP_Syncrony_cols',
'static_feautre_LOC+dynamic_feature_LOC+dynamic_feature_phonation-LOC_columns+DEP_columns',
'static_feautre_LOC+dynamic_feature_LOC+dynamic_feature_phonation-Inter-Vowel Dispersion',
'static_feautre_LOC+dynamic_feature_LOC+dynamic_feature_phonation-formant dependency',
'static_feautre_LOC+dynamic_feature_LOC+dynamic_feature_phonation-GC[VSC]\\textsubscript{inv}',
'static_feautre_LOC+dynamic_feature_LOC+dynamic_feature_phonation-Syncrony[VSC]',
'static_feautre_LOC+dynamic_feature_LOC+dynamic_feature_phonation-GC[P]\\textsubscript{part}']

dfResults_dict=Dict()
for Normalize_way in Normalized_ways_lst:
    file1 = ReadPath+"/"+f"TASLPTABLE-Regression_Norm[{Normalize_way}].xlsx"
    df1 = pd.read_excel(file1,index_col='Unnamed: 0')
    df1 = df1.drop('Unnamed: 0.1', axis=1)
    df1.loc[fusion_indexes,['MSE', 'pear', 'spear', 'CCC']] = df1.loc[fusion_indexes,'ADOS_C/SVR (MAE/pear/spear/CCC)'].str.split('/', expand=True).astype(float).values
    # df1.loc[fusion_indexes,['MSE', 'pear', 'spear', 'CCC']] = df1.loc[fusion_indexes,'ADOS_C/SVR (MAE/pear/spear/CCC)'].str.split('/', expand=True)
    df1.drop('ADOS_C/SVR (MAE/pear/spear/CCC)', axis=1, inplace=True)
    df1.drop('MSE', axis=1, inplace=True)
    dfResults_dict['Regression'][Normalize_way]=df1
    
    
    file2 = ReadPath+"/"+f"TASLPTABLE-Classification_Norm[{Normalize_way}].xlsx"
    df2 = pd.read_excel(file2,index_col='Unnamed: 0')
    df2 = df2.drop('Unnamed: 0.1', axis=1)
 
    
    dfResults_dict['Classification'][Normalize_way]=df2
    
difffResults_dict=Dict()
for Normalize_way in NormalizedNewways_lst:
    for RstType in dfResults_dict.keys():
        difffResults_dict[RstType][Normalize_way] = dfResults_dict[RstType][Normalize_way] - dfResults_dict[RstType]['proposed']
        
        
df=dfResults_dict[RstType][Normalize_way]

ResultOut_pathRoot="./DiffRslts"

for RstType in difffResults_dict.keys():
    for Normalize_way in difffResults_dict[RstType].keys():
        ResultOut_path=f"{ResultOut_pathRoot}/{RstType}/"
        if not os.path.exists(ResultOut_path):
            os.makedirs(ResultOut_path)
        difffResults_dict[RstType][Normalize_way].to_excel(f"{ResultOut_path}/{Normalize_way}-proposed.xlsx")

# %%
difffResults_dict[RstType]
# Out:
# {'func1':                                                     TD vs df_feature_lowMinimal_CSS:ASDTD/SVC  \
#  Unnamed: 0
#  Proximity[P]                                                                            0.000
#  Convergence[P]                                                                          0.000
#  Syncrony[P]                                                                             0.000
#  GC[P]\textsubscript{inv}                                                                0.000
#  GC[P]\textsubscript{part}                                                               0.000
#  Proximity[VSC]                                                                          0.514
#  Convergence[VSC]                                                                        0.121
#  Syncrony[VSC]                                                                           0.021
#  GC[VSC]\textsubscript{inv}                                                              0.035
#  GC[VSC]\textsubscript{part}                                                            -0.185
#  Inter-Vowel Dispersion                                                                 -0.046
#  Intra-Vowel Dispersion                                                                  0.025
#  formant dependency                                                                     -0.035
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                                        NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                                        NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                                        NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                                     NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                                   NaN
#  Proximity[P]                                                                              NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                                        NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                                     NaN
#  formant dependency+Proximity[P]                                                           NaN
#  Proximity[P]                                                                              NaN
#
#                                                      TD vs df_feature_lowMinimal_CSS:f1  \
#  Unnamed: 0
#  Proximity[P]                                                                     0.000
#  Convergence[P]                                                                   0.000
#  Syncrony[P]                                                                      0.000
#  GC[P]\textsubscript{inv}                                                         0.000
#  GC[P]\textsubscript{part}                                                        0.000
#  Proximity[VSC]                                                                   0.623
#  Convergence[VSC]                                                                 0.120
#  Syncrony[VSC]                                                                    0.054
#  GC[VSC]\textsubscript{inv}                                                       0.033
#  GC[VSC]\textsubscript{part}                                                     -0.236
#  Inter-Vowel Dispersion                                                          -0.083
#  Intra-Vowel Dispersion                                                           0.027
#  formant dependency                                                              -0.037
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                                 NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                                 NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                                 NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                              NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                            NaN
#  Proximity[P]                                                                       NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                                 NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                              NaN
#  formant dependency+Proximity[P]                                                    NaN
#  Proximity[P]                                                                       NaN
#
#                                                      TD vs df_feature_moderate_CSS:ASDTD/SVC  \
#  Unnamed: 0
#  Proximity[P]                                                                          0.000
#  Convergence[P]                                                                        0.000
#  Syncrony[P]                                                                           0.000
#  GC[P]\textsubscript{inv}                                                              0.000
#  GC[P]\textsubscript{part}                                                             0.000
#  Proximity[VSC]                                                                        0.515
#  Convergence[VSC]                                                                      0.050
#  Syncrony[VSC]                                                                         0.026
#  GC[VSC]\textsubscript{inv}                                                           -0.063
#  GC[VSC]\textsubscript{part}                                                           0.088
#  Inter-Vowel Dispersion                                                                0.114
#  Intra-Vowel Dispersion                                                                0.012
#  formant dependency                                                                    0.027
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                                      NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                                      NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                                      NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                                   NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                                 NaN
#  Proximity[P]                                                                            NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                                      NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                                   NaN
#  formant dependency+Proximity[P]                                                         NaN
#  Proximity[P]                                                                            NaN
#
#                                                      TD vs df_feature_moderate_CSS:f1  \
#  Unnamed: 0
#  Proximity[P]                                                                   0.000
#  Convergence[P]                                                                 0.000
#  Syncrony[P]                                                                    0.000
#  GC[P]\textsubscript{inv}                                                       0.000
#  GC[P]\textsubscript{part}                                                      0.000
#  Proximity[VSC]                                                                 0.543
#  Convergence[VSC]                                                               0.051
#  Syncrony[VSC]                                                                  0.019
#  GC[VSC]\textsubscript{inv}                                                    -0.065
#  GC[VSC]\textsubscript{part}                                                    0.134
#  Inter-Vowel Dispersion                                                         0.116
#  Intra-Vowel Dispersion                                                         0.006
#  formant dependency                                                            -0.020
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                               NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                               NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                               NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                            NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                          NaN
#  Proximity[P]                                                                     NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                               NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                            NaN
#  formant dependency+Proximity[P]                                                  NaN
#  Proximity[P]                                                                     NaN
#
#                                                      TD vs df_feature_high_CSS:ASDTD/SVC  \
#  Unnamed: 0
#  Proximity[P]                                                                      0.000
#  Convergence[P]                                                                    0.000
#  Syncrony[P]                                                                       0.000
#  GC[P]\textsubscript{inv}                                                          0.000
#  GC[P]\textsubscript{part}                                                         0.000
#  Proximity[VSC]                                                                    0.381
#  Convergence[VSC]                                                                 -0.125
#  Syncrony[VSC]                                                                    -0.015
#  GC[VSC]\textsubscript{inv}                                                        0.040
#  GC[VSC]\textsubscript{part}                                                       0.070
#  Inter-Vowel Dispersion                                                            0.090
#  Intra-Vowel Dispersion                                                           -0.045
#  formant dependency                                                                0.000
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                                  NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                                  NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                                  NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                               NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                             NaN
#  Proximity[P]                                                                        NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                                  NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                               NaN
#  formant dependency+Proximity[P]                                                     NaN
#  Proximity[P]                                                                        NaN
#
#                                                      TD vs df_feature_high_CSS:f1  \
#  Unnamed: 0
#  Proximity[P]                                                               0.000
#  Convergence[P]                                                             0.000
#  Syncrony[P]                                                                0.000
#  GC[P]\textsubscript{inv}                                                   0.000
#  GC[P]\textsubscript{part}                                                  0.000
#  Proximity[VSC]                                                             0.376
#  Convergence[VSC]                                                          -0.130
#  Syncrony[VSC]                                                             -0.011
#  GC[VSC]\textsubscript{inv}                                                 0.064
#  GC[VSC]\textsubscript{part}                                                0.072
#  Inter-Vowel Dispersion                                                     0.104
#  Intra-Vowel Dispersion                                                    -0.023
#  formant dependency                                                         0.000
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                           NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                           NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                           NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                        NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                      NaN
#  Proximity[P]                                                                 NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                           NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                        NaN
#  formant dependency+Proximity[P]                                              NaN
#  Proximity[P]                                                                 NaN
#
#                                                      ASDTD/SVC  num_ASD  \
#  Unnamed: 0
#  Proximity[P]                                              NaN      NaN
#  Convergence[P]                                            NaN      NaN
#  Syncrony[P]                                               NaN      NaN
#  GC[P]\textsubscript{inv}                                  NaN      NaN
#  GC[P]\textsubscript{part}                                 NaN      NaN
#  Proximity[VSC]                                            NaN      NaN
#  Convergence[VSC]                                          NaN      NaN
#  Syncrony[VSC]                                             NaN      NaN
#  GC[VSC]\textsubscript{inv}                                NaN      NaN
#  GC[VSC]\textsubscript{part}                               NaN      NaN
#  Inter-Vowel Dispersion                                    NaN      NaN
#  Intra-Vowel Dispersion                                    NaN      NaN
#  formant dependency                                        NaN      NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...      0.000      0.0
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...     -0.025      0.0
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...      0.000      0.0
#  GC[P]\textsubscript{part}+Syncrony[P]                   0.000      0.0
#  GC[VSC]\textsubscript{inv}+Proximity[P]                 0.025      0.0
#  Proximity[P]                                            0.000      0.0
#  formant dependency+GC[P]\textsubscript{inv}+Pro...     -0.101      0.0
#  GC[P]\textsubscript{inv}+Proximity[P]                   0.000      0.0
#  formant dependency+Proximity[P]                        -0.050      0.0
#  Proximity[P]                                            0.000      0.0
#
#                                                      num_TD     f1
#  Unnamed: 0
#  Proximity[P]                                           NaN    NaN
#  Convergence[P]                                         NaN    NaN
#  Syncrony[P]                                            NaN    NaN
#  GC[P]\textsubscript{inv}                               NaN    NaN
#  GC[P]\textsubscript{part}                              NaN    NaN
#  Proximity[VSC]                                         NaN    NaN
#  Convergence[VSC]                                       NaN    NaN
#  Syncrony[VSC]                                          NaN    NaN
#  GC[VSC]\textsubscript{inv}                             NaN    NaN
#  GC[VSC]\textsubscript{part}                            NaN    NaN
#  Inter-Vowel Dispersion                                 NaN    NaN
#  Intra-Vowel Dispersion                                 NaN    NaN
#  formant dependency                                     NaN    NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...     0.0  0.000
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...     0.0 -0.028
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...     0.0  0.000
#  GC[P]\textsubscript{part}+Syncrony[P]                  0.0  0.000
#  GC[VSC]\textsubscript{inv}+Proximity[P]                0.0  0.021
#  Proximity[P]                                           0.0  0.000
#  formant dependency+GC[P]\textsubscript{inv}+Pro...     0.0 -0.114
#  GC[P]\textsubscript{inv}+Proximity[P]                  0.0  0.000
#  formant dependency+Proximity[P]                        0.0 -0.044
#  Proximity[P]                                           0.0  0.000  ,
#  'func2':                                                     TD vs df_feature_lowMinimal_CSS:ASDTD/SVC  \
#  Unnamed: 0
#  Proximity[P]                                                                            0.000
#  Convergence[P]                                                                          0.000
#  Syncrony[P]                                                                             0.000
#  GC[P]\textsubscript{inv}                                                                0.000
#  GC[P]\textsubscript{part}                                                               0.000
#  Proximity[VSC]                                                                          0.514
#  Convergence[VSC]                                                                        0.071
#  Syncrony[VSC]                                                                           0.014
#  GC[VSC]\textsubscript{inv}                                                              0.035
#  GC[VSC]\textsubscript{part}                                                            -0.150
#  Inter-Vowel Dispersion                                                                 -0.025
#  Intra-Vowel Dispersion                                                                 -0.036
#  formant dependency                                                                     -0.082
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                                        NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                                        NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                                        NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                                     NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                                   NaN
#  Proximity[P]                                                                              NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                                        NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                                     NaN
#  formant dependency+Proximity[P]                                                           NaN
#  Proximity[P]                                                                              NaN
#
#                                                      TD vs df_feature_lowMinimal_CSS:f1  \
#  Unnamed: 0
#  Proximity[P]                                                                     0.000
#  Convergence[P]                                                                   0.000
#  Syncrony[P]                                                                      0.000
#  GC[P]\textsubscript{inv}                                                         0.000
#  GC[P]\textsubscript{part}                                                        0.000
#  Proximity[VSC]                                                                   0.623
#  Convergence[VSC]                                                                 0.066
#  Syncrony[VSC]                                                                    0.037
#  GC[VSC]\textsubscript{inv}                                                       0.033
#  GC[VSC]\textsubscript{part}                                                     -0.182
#  Inter-Vowel Dispersion                                                          -0.020
#  Intra-Vowel Dispersion                                                          -0.034
#  formant dependency                                                              -0.097
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                                 NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                                 NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                                 NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                              NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                            NaN
#  Proximity[P]                                                                       NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                                 NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                              NaN
#  formant dependency+Proximity[P]                                                    NaN
#  Proximity[P]                                                                       NaN
#
#                                                      TD vs df_feature_moderate_CSS:ASDTD/SVC  \
#  Unnamed: 0
#  Proximity[P]                                                                          0.000
#  Convergence[P]                                                                        0.000
#  Syncrony[P]                                                                           0.000
#  GC[P]\textsubscript{inv}                                                              0.000
#  GC[P]\textsubscript{part}                                                             0.000
#  Proximity[VSC]                                                                        0.515
#  Convergence[VSC]                                                                     -0.025
#  Syncrony[VSC]                                                                         0.064
#  GC[VSC]\textsubscript{inv}                                                           -0.038
#  GC[VSC]\textsubscript{part}                                                           0.088
#  Inter-Vowel Dispersion                                                                0.163
#  Intra-Vowel Dispersion                                                                0.025
#  formant dependency                                                                   -0.023
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                                      NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                                      NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                                      NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                                   NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                                 NaN
#  Proximity[P]                                                                            NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                                      NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                                   NaN
#  formant dependency+Proximity[P]                                                         NaN
#  Proximity[P]                                                                            NaN
#
#                                                      TD vs df_feature_moderate_CSS:f1  \
#  Unnamed: 0
#  Proximity[P]                                                                   0.000
#  Convergence[P]                                                                 0.000
#  Syncrony[P]                                                                    0.000
#  GC[P]\textsubscript{inv}                                                       0.000
#  GC[P]\textsubscript{part}                                                      0.000
#  Proximity[VSC]                                                                 0.543
#  Convergence[VSC]                                                              -0.027
#  Syncrony[VSC]                                                                  0.066
#  GC[VSC]\textsubscript{inv}                                                    -0.040
#  GC[VSC]\textsubscript{part}                                                    0.134
#  Inter-Vowel Dispersion                                                         0.159
#  Intra-Vowel Dispersion                                                         0.013
#  formant dependency                                                            -0.081
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                               NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                               NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                               NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                            NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                          NaN
#  Proximity[P]                                                                     NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                               NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                            NaN
#  formant dependency+Proximity[P]                                                  NaN
#  Proximity[P]                                                                     NaN
#
#                                                      TD vs df_feature_high_CSS:ASDTD/SVC  \
#  Unnamed: 0
#  Proximity[P]                                                                      0.000
#  Convergence[P]                                                                    0.000
#  Syncrony[P]                                                                       0.000
#  GC[P]\textsubscript{inv}                                                          0.000
#  GC[P]\textsubscript{part}                                                         0.000
#  Proximity[VSC]                                                                    0.356
#  Convergence[VSC]                                                                 -0.135
#  Syncrony[VSC]                                                                    -0.065
#  GC[VSC]\textsubscript{inv}                                                        0.040
#  GC[VSC]\textsubscript{part}                                                       0.030
#  Inter-Vowel Dispersion                                                            0.054
#  Intra-Vowel Dispersion                                                           -0.015
#  formant dependency                                                                0.000
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                                  NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                                  NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                                  NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                               NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                             NaN
#  Proximity[P]                                                                        NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                                  NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                               NaN
#  formant dependency+Proximity[P]                                                     NaN
#  Proximity[P]                                                                        NaN
#
#                                                      TD vs df_feature_high_CSS:f1  \
#  Unnamed: 0
#  Proximity[P]                                                               0.000
#  Convergence[P]                                                             0.000
#  Syncrony[P]                                                                0.000
#  GC[P]\textsubscript{inv}                                                   0.000
#  GC[P]\textsubscript{part}                                                  0.000
#  Proximity[VSC]                                                             0.356
#  Convergence[VSC]                                                          -0.156
#  Syncrony[VSC]                                                             -0.089
#  GC[VSC]\textsubscript{inv}                                                 0.064
#  GC[VSC]\textsubscript{part}                                                0.024
#  Inter-Vowel Dispersion                                                     0.070
#  Intra-Vowel Dispersion                                                    -0.008
#  formant dependency                                                         0.000
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                           NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                           NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                           NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                        NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                      NaN
#  Proximity[P]                                                                 NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                           NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                        NaN
#  formant dependency+Proximity[P]                                              NaN
#  Proximity[P]                                                                 NaN
#
#                                                      ASDTD/SVC  num_ASD  \
#  Unnamed: 0
#  Proximity[P]                                              NaN      NaN
#  Convergence[P]                                            NaN      NaN
#  Syncrony[P]                                               NaN      NaN
#  GC[P]\textsubscript{inv}                                  NaN      NaN
#  GC[P]\textsubscript{part}                                 NaN      NaN
#  Proximity[VSC]                                            NaN      NaN
#  Convergence[VSC]                                          NaN      NaN
#  Syncrony[VSC]                                             NaN      NaN
#  GC[VSC]\textsubscript{inv}                                NaN      NaN
#  GC[VSC]\textsubscript{part}                               NaN      NaN
#  Inter-Vowel Dispersion                                    NaN      NaN
#  Intra-Vowel Dispersion                                    NaN      NaN
#  formant dependency                                        NaN      NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...      0.000      0.0
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...      0.000      0.0
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...      0.000      0.0
#  GC[P]\textsubscript{part}+Syncrony[P]                   0.000      0.0
#  GC[VSC]\textsubscript{inv}+Proximity[P]                 0.038      0.0
#  Proximity[P]                                            0.000      0.0
#  formant dependency+GC[P]\textsubscript{inv}+Pro...     -0.071      0.0
#  GC[P]\textsubscript{inv}+Proximity[P]                   0.000      0.0
#  formant dependency+Proximity[P]                        -0.050      0.0
#  Proximity[P]                                            0.000      0.0
#
#                                                      num_TD     f1
#  Unnamed: 0
#  Proximity[P]                                           NaN    NaN
#  Convergence[P]                                         NaN    NaN
#  Syncrony[P]                                            NaN    NaN
#  GC[P]\textsubscript{inv}                               NaN    NaN
#  GC[P]\textsubscript{part}                              NaN    NaN
#  Proximity[VSC]                                         NaN    NaN
#  Convergence[VSC]                                       NaN    NaN
#  Syncrony[VSC]                                          NaN    NaN
#  GC[VSC]\textsubscript{inv}                             NaN    NaN
#  GC[VSC]\textsubscript{part}                            NaN    NaN
#  Inter-Vowel Dispersion                                 NaN    NaN
#  Intra-Vowel Dispersion                                 NaN    NaN
#  formant dependency                                     NaN    NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...     0.0  0.000
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...     0.0  0.000
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...     0.0  0.000
#  GC[P]\textsubscript{part}+Syncrony[P]                  0.0  0.000
#  GC[VSC]\textsubscript{inv}+Proximity[P]                0.0  0.038
#  Proximity[P]                                           0.0  0.000
#  formant dependency+GC[P]\textsubscript{inv}+Pro...     0.0 -0.078
#  GC[P]\textsubscript{inv}+Proximity[P]                  0.0  0.000
#  formant dependency+Proximity[P]                        0.0 -0.044
#  Proximity[P]                                           0.0  0.000  ,
#  'func3':                                                     TD vs df_feature_lowMinimal_CSS:ASDTD/SVC  \
#  Unnamed: 0
#  Proximity[P]                                                                            0.000
#  Convergence[P]                                                                          0.000
#  Syncrony[P]                                                                             0.000
#  GC[P]\textsubscript{inv}                                                                0.000
#  GC[P]\textsubscript{part}                                                               0.000
#  Proximity[VSC]                                                                          0.514
#  Convergence[VSC]                                                                        0.036
#  Syncrony[VSC]                                                                           0.068
#  GC[VSC]\textsubscript{inv}                                                              0.035
#  GC[VSC]\textsubscript{part}                                                            -0.150
#  Inter-Vowel Dispersion                                                                 -0.025
#  Intra-Vowel Dispersion                                                                  0.000
#  formant dependency                                                                     -0.025
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                                        NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                                        NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                                        NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                                     NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                                   NaN
#  Proximity[P]                                                                              NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                                        NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                                     NaN
#  formant dependency+Proximity[P]                                                           NaN
#  Proximity[P]                                                                              NaN
#
#                                                      TD vs df_feature_lowMinimal_CSS:f1  \
#  Unnamed: 0
#  Proximity[P]                                                                     0.000
#  Convergence[P]                                                                   0.000
#  Syncrony[P]                                                                      0.000
#  GC[P]\textsubscript{inv}                                                         0.000
#  GC[P]\textsubscript{part}                                                        0.000
#  Proximity[VSC]                                                                   0.623
#  Convergence[VSC]                                                                 0.033
#  Syncrony[VSC]                                                                    0.109
#  GC[VSC]\textsubscript{inv}                                                       0.033
#  GC[VSC]\textsubscript{part}                                                     -0.182
#  Inter-Vowel Dispersion                                                          -0.020
#  Intra-Vowel Dispersion                                                           0.000
#  formant dependency                                                              -0.025
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                                 NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                                 NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                                 NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                              NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                            NaN
#  Proximity[P]                                                                       NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                                 NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                              NaN
#  formant dependency+Proximity[P]                                                    NaN
#  Proximity[P]                                                                       NaN
#
#                                                      TD vs df_feature_moderate_CSS:ASDTD/SVC  \
#  Unnamed: 0
#  Proximity[P]                                                                          0.000
#  Convergence[P]                                                                        0.000
#  Syncrony[P]                                                                           0.000
#  GC[P]\textsubscript{inv}                                                              0.000
#  GC[P]\textsubscript{part}                                                             0.000
#  Proximity[VSC]                                                                        0.515
#  Convergence[VSC]                                                                      0.025
#  Syncrony[VSC]                                                                         0.089
#  GC[VSC]\textsubscript{inv}                                                           -0.051
#  GC[VSC]\textsubscript{part}                                                           0.088
#  Inter-Vowel Dispersion                                                                0.051
#  Intra-Vowel Dispersion                                                                0.000
#  formant dependency                                                                   -0.010
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                                      NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                                      NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                                      NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                                   NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                                 NaN
#  Proximity[P]                                                                            NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                                      NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                                   NaN
#  formant dependency+Proximity[P]                                                         NaN
#  Proximity[P]                                                                            NaN
#
#                                                      TD vs df_feature_moderate_CSS:f1  \
#  Unnamed: 0
#  Proximity[P]                                                                   0.000
#  Convergence[P]                                                                 0.000
#  Syncrony[P]                                                                    0.000
#  GC[P]\textsubscript{inv}                                                       0.000
#  GC[P]\textsubscript{part}                                                      0.000
#  Proximity[VSC]                                                                 0.543
#  Convergence[VSC]                                                               0.026
#  Syncrony[VSC]                                                                  0.101
#  GC[VSC]\textsubscript{inv}                                                    -0.054
#  GC[VSC]\textsubscript{part}                                                    0.134
#  Inter-Vowel Dispersion                                                         0.049
#  Intra-Vowel Dispersion                                                         0.000
#  formant dependency                                                            -0.074
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                               NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                               NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                               NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                            NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                          NaN
#  Proximity[P]                                                                     NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                               NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                            NaN
#  formant dependency+Proximity[P]                                                  NaN
#  Proximity[P]                                                                     NaN
#
#                                                      TD vs df_feature_high_CSS:ASDTD/SVC  \
#  Unnamed: 0
#  Proximity[P]                                                                      0.000
#  Convergence[P]                                                                    0.000
#  Syncrony[P]                                                                       0.000
#  GC[P]\textsubscript{inv}                                                          0.000
#  GC[P]\textsubscript{part}                                                         0.000
#  Proximity[VSC]                                                                    0.381
#  Convergence[VSC]                                                                 -0.150
#  Syncrony[VSC]                                                                    -0.040
#  GC[VSC]\textsubscript{inv}                                                        0.000
#  GC[VSC]\textsubscript{part}                                                       0.051
#  Inter-Vowel Dispersion                                                            0.090
#  Intra-Vowel Dispersion                                                           -0.015
#  formant dependency                                                                0.000
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                                  NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                                  NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                                  NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                               NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                             NaN
#  Proximity[P]                                                                        NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                                  NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                               NaN
#  formant dependency+Proximity[P]                                                     NaN
#  Proximity[P]                                                                        NaN
#
#                                                      TD vs df_feature_high_CSS:f1  \
#  Unnamed: 0
#  Proximity[P]                                                               0.000
#  Convergence[P]                                                             0.000
#  Syncrony[P]                                                                0.000
#  GC[P]\textsubscript{inv}                                                   0.000
#  GC[P]\textsubscript{part}                                                  0.000
#  Proximity[VSC]                                                             0.376
#  Convergence[VSC]                                                          -0.166
#  Syncrony[VSC]                                                             -0.049
#  GC[VSC]\textsubscript{inv}                                                 0.022
#  GC[VSC]\textsubscript{part}                                                0.020
#  Inter-Vowel Dispersion                                                     0.104
#  Intra-Vowel Dispersion                                                    -0.008
#  formant dependency                                                         0.000
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                           NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                           NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                           NaN
# ...
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                                        NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                                        NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                                        NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                                     NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                                   NaN
#  Proximity[P]                                                                              NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                                        NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                                     NaN
#  formant dependency+Proximity[P]                                                           NaN
#  Proximity[P]                                                                              NaN
#
#                                                      TD vs df_feature_lowMinimal_CSS:f1  \
#  Unnamed: 0
#  Proximity[P]                                                                     0.000
#  Convergence[P]                                                                   0.000
#  Syncrony[P]                                                                      0.000
#  GC[P]\textsubscript{inv}                                                         0.000
#  GC[P]\textsubscript{part}                                                        0.000
#  Proximity[VSC]                                                                   0.592
#  Convergence[VSC]                                                                 0.026
#  Syncrony[VSC]                                                                    0.183
#  GC[VSC]\textsubscript{inv}                                                       0.033
#  GC[VSC]\textsubscript{part}                                                     -0.163
#  Inter-Vowel Dispersion                                                           0.000
#  Intra-Vowel Dispersion                                                          -0.131
#  formant dependency                                                              -0.119
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                                 NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                                 NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                                 NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                              NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                            NaN
#  Proximity[P]                                                                       NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                                 NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                              NaN
#  formant dependency+Proximity[P]                                                    NaN
#  Proximity[P]                                                                       NaN
#
#                                                      TD vs df_feature_moderate_CSS:ASDTD/SVC  \
#  Unnamed: 0
#  Proximity[P]                                                                          0.000
#  Convergence[P]                                                                        0.000
#  Syncrony[P]                                                                           0.000
#  GC[P]\textsubscript{inv}                                                              0.000
#  GC[P]\textsubscript{part}                                                             0.000
#  Proximity[VSC]                                                                        0.490
#  Convergence[VSC]                                                                     -0.163
#  Syncrony[VSC]                                                                         0.014
#  GC[VSC]\textsubscript{inv}                                                           -0.088
#  GC[VSC]\textsubscript{part}                                                           0.062
#  Inter-Vowel Dispersion                                                                0.050
#  Intra-Vowel Dispersion                                                                0.038
#  formant dependency                                                                   -0.024
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                                      NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                                      NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                                      NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                                   NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                                 NaN
#  Proximity[P]                                                                            NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                                      NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                                   NaN
#  formant dependency+Proximity[P]                                                         NaN
#  Proximity[P]                                                                            NaN
#
#                                                      TD vs df_feature_moderate_CSS:f1  \
#  Unnamed: 0
#  Proximity[P]                                                                   0.000
#  Convergence[P]                                                                 0.000
#  Syncrony[P]                                                                    0.000
#  GC[P]\textsubscript{inv}                                                       0.000
#  GC[P]\textsubscript{part}                                                      0.000
#  Proximity[VSC]                                                                 0.507
#  Convergence[VSC]                                                              -0.178
#  Syncrony[VSC]                                                                 -0.011
#  GC[VSC]\textsubscript{inv}                                                    -0.091
#  GC[VSC]\textsubscript{part}                                                    0.107
#  Inter-Vowel Dispersion                                                         0.050
#  Intra-Vowel Dispersion                                                         0.019
#  formant dependency                                                            -0.053
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                               NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                               NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                               NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                            NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                          NaN
#  Proximity[P]                                                                     NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                               NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                            NaN
#  formant dependency+Proximity[P]                                                  NaN
#  Proximity[P]                                                                     NaN
#
#                                                      TD vs df_feature_high_CSS:ASDTD/SVC  \
#  Unnamed: 0
#  Proximity[P]                                                                      0.000
#  Convergence[P]                                                                    0.000
#  Syncrony[P]                                                                       0.000
#  GC[P]\textsubscript{inv}                                                          0.000
#  GC[P]\textsubscript{part}                                                         0.000
#  Proximity[VSC]                                                                    0.341
#  Convergence[VSC]                                                                 -0.105
#  Syncrony[VSC]                                                                     0.000
#  GC[VSC]\textsubscript{inv}                                                        0.040
#  GC[VSC]\textsubscript{part}                                                       0.040
#  Inter-Vowel Dispersion                                                            0.039
#  Intra-Vowel Dispersion                                                            0.000
#  formant dependency                                                                0.010
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                                  NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                                  NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                                  NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                               NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                             NaN
#  Proximity[P]                                                                        NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                                  NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                               NaN
#  formant dependency+Proximity[P]                                                     NaN
#  Proximity[P]                                                                        NaN
#
#                                                      TD vs df_feature_high_CSS:f1  \
#  Unnamed: 0
#  Proximity[P]                                                               0.000
#  Convergence[P]                                                             0.000
#  Syncrony[P]                                                                0.000
#  GC[P]\textsubscript{inv}                                                   0.000
#  GC[P]\textsubscript{part}                                                  0.000
#  Proximity[VSC]                                                             0.337
#  Convergence[VSC]                                                          -0.136
#  Syncrony[VSC]                                                              0.000
#  GC[VSC]\textsubscript{inv}                                                 0.064
#  GC[VSC]\textsubscript{part}                                                0.046
#  Inter-Vowel Dispersion                                                     0.055
#  Intra-Vowel Dispersion                                                     0.000
#  formant dependency                                                         0.030
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                           NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...                           NaN
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                           NaN
#  GC[P]\textsubscript{part}+Syncrony[P]                                        NaN
#  GC[VSC]\textsubscript{inv}+Proximity[P]                                      NaN
#  Proximity[P]                                                                 NaN
#  formant dependency+GC[P]\textsubscript{inv}+Pro...                           NaN
#  GC[P]\textsubscript{inv}+Proximity[P]                                        NaN
#  formant dependency+Proximity[P]                                              NaN
#  Proximity[P]                                                                 NaN
#
#                                                      ASDTD/SVC  num_ASD  \
#  Unnamed: 0
#  Proximity[P]                                              NaN      NaN
#  Convergence[P]                                            NaN      NaN
#  Syncrony[P]                                               NaN      NaN
#  GC[P]\textsubscript{inv}                                  NaN      NaN
#  GC[P]\textsubscript{part}                                 NaN      NaN
#  Proximity[VSC]                                            NaN      NaN
#  Convergence[VSC]                                          NaN      NaN
#  Syncrony[VSC]                                             NaN      NaN
#  GC[VSC]\textsubscript{inv}                                NaN      NaN
#  GC[VSC]\textsubscript{part}                               NaN      NaN
#  Inter-Vowel Dispersion                                    NaN      NaN
#  Intra-Vowel Dispersion                                    NaN      NaN
#  formant dependency                                        NaN      NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...      0.000      0.0
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...      0.000      0.0
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...      0.000      0.0
#  GC[P]\textsubscript{part}+Syncrony[P]                   0.000      0.0
#  GC[VSC]\textsubscript{inv}+Proximity[P]                 0.050      0.0
#  Proximity[P]                                            0.000      0.0
#  formant dependency+GC[P]\textsubscript{inv}+Pro...     -0.046      0.0
#  GC[P]\textsubscript{inv}+Proximity[P]                   0.000      0.0
#  formant dependency+Proximity[P]                        -0.050      0.0
#  Proximity[P]                                            0.000      0.0
#
#                                                      num_TD     f1
#  Unnamed: 0
#  Proximity[P]                                           NaN    NaN
#  Convergence[P]                                         NaN    NaN
#  Syncrony[P]                                            NaN    NaN
#  GC[P]\textsubscript{inv}                               NaN    NaN
#  GC[P]\textsubscript{part}                              NaN    NaN
#  Proximity[VSC]                                         NaN    NaN
#  Convergence[VSC]                                       NaN    NaN
#  Syncrony[VSC]                                          NaN    NaN
#  GC[VSC]\textsubscript{inv}                             NaN    NaN
#  GC[VSC]\textsubscript{part}                            NaN    NaN
#  Inter-Vowel Dispersion                                 NaN    NaN
#  Intra-Vowel Dispersion                                 NaN    NaN
#  formant dependency                                     NaN    NaN
#  Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...     0.0  0.000
#  Inter-Vowel Dispersion+GC[P]\textsubscript{part...     0.0  0.000
#  GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...     0.0  0.000
#  GC[P]\textsubscript{part}+Syncrony[P]                  0.0  0.000
#  GC[VSC]\textsubscript{inv}+Proximity[P]                0.0  0.056
#  Proximity[P]                                           0.0  0.000
#  formant dependency+GC[P]\textsubscript{inv}+Pro...     0.0 -0.056
#  GC[P]\textsubscript{inv}+Proximity[P]                  0.0  0.000
#  formant dependency+Proximity[P]                        0.0 -0.044
#  Proximity[P]                                           0.0  0.000  }
