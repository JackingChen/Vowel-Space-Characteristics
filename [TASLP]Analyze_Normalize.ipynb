# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed Jun 14 17:37:15 2023

@author: jack
"""

import pandas as pd
import argparse
import os
from addict import Dict
def get_args():
    # we add compulsary arguments as named arguments for readability
    parser = argparse.ArgumentParser()
    parser.add_argument('--Reference_Normalize_way', default='proposed',
                            help='')

    args = parser.parse_args(args=[])
    return args
args = get_args()

ReadPath='/media/jack/workspace/DisVoice/RESULTS/Merged_xlsx/'
Normalized_ways_lst=['func1','func2','func3','func4','func7','func10','func13','func14','func15',
                     'func16','func17','proposed','None']
NormalizedNewways_lst = [n for n in Normalized_ways_lst if n != args.Reference_Normalize_way]


fusion_indexes_low=[
'Inter-Vowel Dispersion+GC[P]\\textsubscript{inv}+GC[P]\\textsubscript{part}+Syncrony[P]',
'Inter-Vowel Dispersion+GC[P]\\textsubscript{part}+Syncrony[P]',
'GC[P]\\textsubscript{inv}+GC[P]\\textsubscript{part}+Syncrony[P]',
'GC[P]\\textsubscript{part}+Syncrony[P]',
]
fusion_indexes_mid=[
'GC[VSC]\\textsubscript{inv}+Proximity[P]', 
'Proximity[P]',

]
fusion_indexes_high=[
'Proximity[P]',
'formant dependency+GC[P]\\textsubscript{inv}+Proximity[P]',
'formant dependency+Proximity[P]',
'GC[P]\\textsubscript{inv}+Proximity[P]',
]
fusion_indexes_Regress=[
'static_feautre_LOC+dynamic_feature_LOC+dynamic_feature_phonation-LOC_columns+DEP_columns+LOCDEP_Trend_D_cols+LOCDEP_Syncrony_cols',
'static_feautre_LOC+dynamic_feature_LOC+dynamic_feature_phonation-LOC_columns+DEP_columns+LOCDEP_Trend_D_cols',
'static_feautre_LOC+dynamic_feature_LOC+dynamic_feature_phonation-LOC_columns+DEP_columns+LOCDEP_Syncrony_cols',
'static_feautre_LOC+dynamic_feature_LOC+dynamic_feature_phonation-LOC_columns+DEP_columns',
'static_feautre_LOC+dynamic_feature_LOC+dynamic_feature_phonation-Inter-Vowel Dispersion',
'static_feautre_LOC+dynamic_feature_LOC+dynamic_feature_phonation-formant dependency',
'static_feautre_LOC+dynamic_feature_LOC+dynamic_feature_phonation-GC[VSC]\\textsubscript{inv}',
'static_feautre_LOC+dynamic_feature_LOC+dynamic_feature_phonation-Syncrony[VSC]',
'static_feautre_LOC+dynamic_feature_LOC+dynamic_feature_phonation-GC[P]\\textsubscript{part}'
]
column_low=['TD vs df_feature_lowMinimal_CSS:ASDTD/SVC',	'TD vs df_feature_lowMinimal_CSS:f1']
column_mid=['TD vs df_feature_moderate_CSS:ASDTD/SVC',	'TD vs df_feature_moderate_CSS:f1']
column_high=['TD vs df_feature_high_CSS:ASDTD/SVC',	'TD vs df_feature_high_CSS:f1']
column_swap=['ASDTD/SVC','f1']
column_drop=['ASDTD/SVC','num_ASD','num_TD','f1']


dfResults_dict=Dict()
for Normalize_way in Normalized_ways_lst:
    file1 = ReadPath+"/"+f"TASLPTABLE-Regression_Norm[{Normalize_way}].xlsx"
    df1 = pd.read_excel(file1,index_col='Unnamed: 0')
    df1 = df1.drop('Unnamed: 0.1', axis=1)
    df1.loc[fusion_indexes_Regress,['MSE', 'pear', 'spear', 'CCC']] = df1.loc[fusion_indexes_Regress,'ADOS_C/SVR (MAE/pear/spear/CCC)'].str.split('/', expand=True).astype(float).values
    # df1.loc[fusion_indexes,['MSE', 'pear', 'spear', 'CCC']] = df1.loc[fusion_indexes,'ADOS_C/SVR (MAE/pear/spear/CCC)'].str.split('/', expand=True)
    df1.drop('ADOS_C/SVR (MAE/pear/spear/CCC)', axis=1, inplace=True)
    df1.drop('MSE', axis=1, inplace=True)
    dfResults_dict['Regression'][Normalize_way]=df1
    
    
    file2 = ReadPath+"/"+f"TASLPTABLE-Classification_Norm[{Normalize_way}].xlsx"
    df2 = pd.read_excel(file2,index_col='Unnamed: 0')
    df2 = df2.drop('Unnamed: 0.1', axis=1)
    df2.loc[fusion_indexes_low,column_low] = df2.loc[fusion_indexes_low,column_swap]
    df2.loc[fusion_indexes_mid,column_mid] = df2.loc[fusion_indexes_low,column_swap]
    df2.loc[fusion_indexes_high,column_high] = df2.loc[fusion_indexes_low,column_swap]
    df2.drop(column_drop, axis=1, inplace=True)

    dfResults_dict['Classification'][Normalize_way]=df2
    
difffResults_dict=Dict()
for Normalize_way in NormalizedNewways_lst:
    for RstType in dfResults_dict.keys():
        difffResults_dict[RstType][Normalize_way] = dfResults_dict[RstType][Normalize_way] - dfResults_dict[RstType][args.Reference_Normalize_way]
        
        
df=dfResults_dict[RstType][Normalize_way]

ResultOut_pathRoot="./DiffRslts"

for RstType in difffResults_dict.keys():
    for Normalize_way in difffResults_dict[RstType].keys():
        ResultOut_path=f"{ResultOut_pathRoot}/{RstType}/"
        if not os.path.exists(ResultOut_path):
            os.makedirs(ResultOut_path)
        difffResults_dict[RstType][Normalize_way].to_excel(f"{ResultOut_path}/{Normalize_way}-{args.Reference_Normalize_way}.xlsx")

# %%
file2 = ReadPath+"/"+f"TASLPTABLE-Classification_Norm[{Normalize_way}].xlsx"
df2 = pd.read_excel(file2,index_col='Unnamed: 0')
df2 = df2.drop('Unnamed: 0.1', axis=1)
df2.loc[fusion_indexes_low,column_low] = df2.loc[fusion_indexes_low,column_swap]
print(df2)
# Out:
#                                                     TD vs df_feature_lowMinimal_CSS:ASDTD/SVC  \
# Unnamed: 0
# Proximity[P]                                                                            0.675
# Convergence[P]                                                                          0.661
# Syncrony[P]                                                                             0.732
# GC[P]\textsubscript{inv}                                                                0.782
# GC[P]\textsubscript{part}                                                               0.746
# Proximity[VSC]                                                                          0.396
# Convergence[VSC]                                                                        0.636
# Syncrony[VSC]                                                                           0.368
# GC[VSC]\textsubscript{inv}                                                              0.611
# GC[VSC]\textsubscript{part}                                                             0.407
# Inter-Vowel Dispersion                                                                  0.436
# Intra-Vowel Dispersion                                                                  0.586
# formant dependency                                                                      0.539
# Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                                        NaN
# Inter-Vowel Dispersion+GC[P]\textsubscript{part...                                        NaN
# GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                                        NaN
# GC[P]\textsubscript{part}+Syncrony[P]                                                     NaN
# GC[VSC]\textsubscript{inv}+Proximity[P]                                                   NaN
# Proximity[P]                                                                              NaN
# formant dependency+GC[P]\textsubscript{inv}+Pro...                                        NaN
# GC[P]\textsubscript{inv}+Proximity[P]                                                     NaN
# formant dependency+Proximity[P]                                                           NaN
# Proximity[P]                                                                              NaN
#
#                                                     TD vs df_feature_lowMinimal_CSS:f1  \
# Unnamed: 0
# Proximity[P]                                                                     0.678
# Convergence[P]                                                                   0.662
# Syncrony[P]                                                                      0.729
# GC[P]\textsubscript{inv}                                                         0.785
# GC[P]\textsubscript{part}                                                        0.751
# Proximity[VSC]                                                                   0.376
# Convergence[VSC]                                                                 0.636
# Syncrony[VSC]                                                                    0.369
# GC[VSC]\textsubscript{inv}                                                       0.609
# GC[VSC]\textsubscript{part}                                                      0.399
# Inter-Vowel Dispersion                                                           0.379
# Intra-Vowel Dispersion                                                           0.582
# formant dependency                                                               0.539
# Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                                 NaN
# Inter-Vowel Dispersion+GC[P]\textsubscript{part...                                 NaN
# GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                                 NaN
# GC[P]\textsubscript{part}+Syncrony[P]                                              NaN
# GC[VSC]\textsubscript{inv}+Proximity[P]                                            NaN
# Proximity[P]                                                                       NaN
# formant dependency+GC[P]\textsubscript{inv}+Pro...                                 NaN
# GC[P]\textsubscript{inv}+Proximity[P]                                              NaN
# formant dependency+Proximity[P]                                                    NaN
# Proximity[P]                                                                       NaN
#
#                                                     TD vs df_feature_moderate_CSS:ASDTD/SVC  \
# Unnamed: 0
# Proximity[P]                                                                          0.810
# Convergence[P]                                                                        0.460
# Syncrony[P]                                                                           0.597
# GC[P]\textsubscript{inv}                                                              0.635
# GC[P]\textsubscript{part}                                                             0.509
# Proximity[VSC]                                                                        0.447
# Convergence[VSC]                                                                      0.535
# Syncrony[VSC]                                                                         0.486
# GC[VSC]\textsubscript{inv}                                                            0.711
# GC[VSC]\textsubscript{part}                                                           0.610
# Inter-Vowel Dispersion                                                                0.533
# Intra-Vowel Dispersion                                                                0.612
# formant dependency                                                                    0.472
# Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                                      NaN
# Inter-Vowel Dispersion+GC[P]\textsubscript{part...                                      NaN
# GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                                      NaN
# GC[P]\textsubscript{part}+Syncrony[P]                                                   NaN
# GC[VSC]\textsubscript{inv}+Proximity[P]                                                 NaN
# Proximity[P]                                                                            NaN
# formant dependency+GC[P]\textsubscript{inv}+Pro...                                      NaN
# GC[P]\textsubscript{inv}+Proximity[P]                                                   NaN
# formant dependency+Proximity[P]                                                         NaN
# Proximity[P]                                                                            NaN
#
#                                                     TD vs df_feature_moderate_CSS:f1  \
# Unnamed: 0
# Proximity[P]                                                                   0.799
# Convergence[P]                                                                 0.429
# Syncrony[P]                                                                    0.598
# GC[P]\textsubscript{inv}                                                       0.636
# GC[P]\textsubscript{part}                                                      0.508
# Proximity[VSC]                                                                 0.432
# Convergence[VSC]                                                               0.528
# Syncrony[VSC]                                                                  0.448
# GC[VSC]\textsubscript{inv}                                                     0.720
# GC[VSC]\textsubscript{part}                                                    0.614
# Inter-Vowel Dispersion                                                         0.533
# Intra-Vowel Dispersion                                                         0.605
# formant dependency                                                             0.453
# Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                               NaN
# Inter-Vowel Dispersion+GC[P]\textsubscript{part...                               NaN
# GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                               NaN
# GC[P]\textsubscript{part}+Syncrony[P]                                            NaN
# GC[VSC]\textsubscript{inv}+Proximity[P]                                          NaN
# Proximity[P]                                                                     NaN
# formant dependency+GC[P]\textsubscript{inv}+Pro...                               NaN
# GC[P]\textsubscript{inv}+Proximity[P]                                            NaN
# formant dependency+Proximity[P]                                                  NaN
# Proximity[P]                                                                     NaN
#
#                                                     TD vs df_feature_high_CSS:ASDTD/SVC  \
# Unnamed: 0
# Proximity[P]                                                                      0.844
# Convergence[P]                                                                    0.485
# Syncrony[P]                                                                       0.529
# GC[P]\textsubscript{inv}                                                          0.634
# GC[P]\textsubscript{part}                                                         0.379
# Proximity[VSC]                                                                    0.623
# Convergence[VSC]                                                                  0.539
# Syncrony[VSC]                                                                     0.494
# GC[VSC]\textsubscript{inv}                                                        0.624
# GC[VSC]\textsubscript{part}                                                       0.520
# Inter-Vowel Dispersion                                                            0.619
# Intra-Vowel Dispersion                                                            0.500
# formant dependency                                                                0.449
# Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                                  NaN
# Inter-Vowel Dispersion+GC[P]\textsubscript{part...                                  NaN
# GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                                  NaN
# GC[P]\textsubscript{part}+Syncrony[P]                                               NaN
# GC[VSC]\textsubscript{inv}+Proximity[P]                                             NaN
# Proximity[P]                                                                        NaN
# formant dependency+GC[P]\textsubscript{inv}+Pro...                                  NaN
# GC[P]\textsubscript{inv}+Proximity[P]                                               NaN
# formant dependency+Proximity[P]                                                     NaN
# Proximity[P]                                                                        NaN
#
#                                                     TD vs df_feature_high_CSS:f1  \
# Unnamed: 0
# Proximity[P]                                                               0.826
# Convergence[P]                                                             0.376
# Syncrony[P]                                                                0.524
# GC[P]\textsubscript{inv}                                                   0.637
# GC[P]\textsubscript{part}                                                  0.321
# Proximity[VSC]                                                             0.622
# Convergence[VSC]                                                           0.537
# Syncrony[VSC]                                                              0.476
# GC[VSC]\textsubscript{inv}                                                 0.626
# GC[VSC]\textsubscript{part}                                                0.461
# Inter-Vowel Dispersion                                                     0.621
# Intra-Vowel Dispersion                                                     0.384
# formant dependency                                                         0.388
# Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...                           NaN
# Inter-Vowel Dispersion+GC[P]\textsubscript{part...                           NaN
# GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...                           NaN
# GC[P]\textsubscript{part}+Syncrony[P]                                        NaN
# GC[VSC]\textsubscript{inv}+Proximity[P]                                      NaN
# Proximity[P]                                                                 NaN
# formant dependency+GC[P]\textsubscript{inv}+Pro...                           NaN
# GC[P]\textsubscript{inv}+Proximity[P]                                        NaN
# formant dependency+Proximity[P]                                              NaN
# Proximity[P]                                                                 NaN
#
#                                                     ASDTD/SVC  num_ASD  \
# Unnamed: 0
# Proximity[P]                                              NaN      NaN
# Convergence[P]                                            NaN      NaN
# Syncrony[P]                                               NaN      NaN
# GC[P]\textsubscript{inv}                                  NaN      NaN
# GC[P]\textsubscript{part}                                 NaN      NaN
# Proximity[VSC]                                            NaN      NaN
# Convergence[VSC]                                          NaN      NaN
# Syncrony[VSC]                                             NaN      NaN
# GC[VSC]\textsubscript{inv}                                NaN      NaN
# GC[VSC]\textsubscript{part}                               NaN      NaN
# Inter-Vowel Dispersion                                    NaN      NaN
# Intra-Vowel Dispersion                                    NaN      NaN
# formant dependency                                        NaN      NaN
# Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...      0.832     14.0
# Inter-Vowel Dispersion+GC[P]\textsubscript{part...      0.782     14.0
# GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...      0.771     14.0
# GC[P]\textsubscript{part}+Syncrony[P]                   0.843     14.0
# GC[VSC]\textsubscript{inv}+Proximity[P]                 0.824     39.0
# Proximity[P]                                            0.810     39.0
# formant dependency+GC[P]\textsubscript{inv}+Pro...      0.845     33.0
# GC[P]\textsubscript{inv}+Proximity[P]                   0.759     33.0
# formant dependency+Proximity[P]                         0.769     33.0
# Proximity[P]                                            0.844     33.0
#
#                                                     num_TD     f1
# Unnamed: 0
# Proximity[P]                                           NaN    NaN
# Convergence[P]                                         NaN    NaN
# Syncrony[P]                                            NaN    NaN
# GC[P]\textsubscript{inv}                               NaN    NaN
# GC[P]\textsubscript{part}                              NaN    NaN
# Proximity[VSC]                                         NaN    NaN
# Convergence[VSC]                                       NaN    NaN
# Syncrony[VSC]                                          NaN    NaN
# GC[VSC]\textsubscript{inv}                             NaN    NaN
# GC[VSC]\textsubscript{part}                            NaN    NaN
# Inter-Vowel Dispersion                                 NaN    NaN
# Intra-Vowel Dispersion                                 NaN    NaN
# formant dependency                                     NaN    NaN
# Inter-Vowel Dispersion+GC[P]\textsubscript{inv}...    20.0  0.842
# Inter-Vowel Dispersion+GC[P]\textsubscript{part...    20.0  0.785
# GC[P]\textsubscript{inv}+GC[P]\textsubscript{pa...    20.0  0.779
# GC[P]\textsubscript{part}+Syncrony[P]                 20.0  0.846
# GC[VSC]\textsubscript{inv}+Proximity[P]               20.0  0.828
# Proximity[P]                                          20.0  0.799
# formant dependency+GC[P]\textsubscript{inv}+Pro...    20.0  0.855
# GC[P]\textsubscript{inv}+Proximity[P]                 20.0  0.759
# formant dependency+Proximity[P]                       20.0  0.763
# Proximity[P]                                          20.0  0.826
